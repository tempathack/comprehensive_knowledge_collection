# %% [markdown]
# # Observability
#
# You can’t fix what you can’t see. Observability includes:
# - **Logs**: event history
# - **Metrics**: time‑series counters/gauges
# - **Traces**: request path across services
