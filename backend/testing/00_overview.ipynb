# %% [markdown]
# # Backend Testing
#
# Unit/integration testing strategies, fixtures, mocking, and API contract testing.
#
# ## Topics
# - (add notebooks in this folder)
#
# ## Notes
# - (key takeaways / gotchas / references)
