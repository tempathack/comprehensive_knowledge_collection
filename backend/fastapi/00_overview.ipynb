# %% [markdown]
# # FastAPI
#
# Core FastAPI patterns: routing, validation, dependencies, auth, testing, and production setup.
#
# ## Topics
# - (add notebooks in this folder)
#
# ## Notes
# - (key takeaways / gotchas / references)
