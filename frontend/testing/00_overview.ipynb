# %% [markdown]
# # Frontend Testing
#
# Component testing, E2E testing, accessibility checks, and CI integration.
#
# ## Topics
# - (add notebooks in this folder)
#
# ## Notes
# - (key takeaways / gotchas / references)
