# %% [markdown]
# # Vue
#
# Core Vue patterns and practical app structure (Composition API, routing, state).
#
# ## Topics
# - (add notebooks in this folder)
#
# ## Notes
# - (key takeaways / gotchas / references)
