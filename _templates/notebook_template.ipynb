# %% [markdown]
# # Title
#
# ## Goals
# -
#
# ## Prerequisites
# -
#
# ## Outline
# 1. Intuition
# 2. From scratch (optional)
# 3. In practice
# 4. Pitfalls + diagnostics
# 5. Exercises + references

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)

# %% [markdown]
# ## Intuition
#
# Explain the idea in plain language. Add a small plot/diagram if possible.

# %% [markdown]
# ## From scratch (optional)
#
# Implement the core concept with NumPy to build intuition.

# %% [markdown]
# ## In practice
#
# Show how the same concept is used with a standard library (sklearn/torch/etc.).

# %% [markdown]
# ## Pitfalls + diagnostics
#
# - Common mistakes
# - How to detect them
# - How to fix them

# %% [markdown]
# ## Exercises
#
# 1.

# %% [markdown]
# ## References
# -
