# %% [markdown]
# # Network Security
#
# Protocols, segmentation, TLS basics, and safe debugging workflows.
#
# ## Topics
# - (add notebooks in this folder)
#
# ## Notes
# - (key takeaways / gotchas / references)
