# %% [markdown]
# # Testing & Quality
#
# Testing pyramid:
# - unit tests (fast, isolated)
# - integration tests (real dependencies)
# - contract tests (consumer/provider)
# - end‑to‑end tests (slow, but valuable)
