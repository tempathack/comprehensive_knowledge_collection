# %% [markdown]
# # Data Storage & Modeling
#
# Pick storage based on access patterns: read/write ratios, latency, consistency needs, and scaling model.

# %% [markdown]
# ## SQL vs NoSQL
# - SQL: strong consistency, joins, transactions
# - NoSQL: flexible schema, horizontal scaling, eventual consistency

# %% [markdown]
# ## Schema evolution
# - Additive changes are safest
# - Backfill data before switching reads
# - Use migrations with rollback plans
