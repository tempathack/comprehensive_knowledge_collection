# %% [markdown]
# # Caching & Queues
#
# Caching reduces latency but adds complexity.
#
# ## Cache patterns
# - Read‑through
# - Write‑through
# - Write‑behind
#
# ## Queues
# - Decouple systems
# - Handle bursty workloads
# - Provide retries and dead‑letter queues
