# %% [markdown]
# # Auth & Security
#
# Authentication answers *who*; authorization answers *what they can do*.
#
# ## Common patterns
# - OAuth2 + OIDC for delegated access
# - JWT access tokens + refresh tokens
# - Role‑based (RBAC) vs attribute‑based (ABAC) access control

# %% [markdown]
# ## JWT anatomy
# A JWT contains header, payload, signature. **Never** store sensitive data in the payload—it is only base64‑encoded, not encrypted.

# %%
# Example JWT structure
header = {"alg": "HS256", "typ": "JWT"}
payload = {"sub": "user123", "exp": 1710000000}
