# %% [markdown]
# # Finance — Overview
#
# This section is a structured, textbook‑style reference. It explains core concepts, system trade‑offs, and practical patterns with examples.

# %% [markdown]
# ## Core topics
# - Time value of money
# - Derivatives
# - Risk
# - Portfolio theory
# - Fixed income
# - Econometrics
