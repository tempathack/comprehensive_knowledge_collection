# %% [markdown]
# # Distance-based time-series regression (KNN)
#
# This folder focuses on **distance-based** supervised learning approaches for time series.
#
# ## Notebooks
# - `k_neighbors_time_series_regressor/overview.ipynb`: implement `KNeighborsTimeSeriesRegressor([...])` from scratch (NumPy) + Plotly demos.
