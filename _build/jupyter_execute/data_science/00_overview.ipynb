# %% [markdown]
# # Data Science — Overview
#
# ## Purpose
# - What this section covers
# - Key questions it answers
#
# ## Topics
# - (to be expanded)
#
# ## References
# - (add sources, docs, papers)

# %%
# placeholder: add code + plots here
