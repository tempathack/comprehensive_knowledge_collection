# %% [markdown]
# # Frontend Security
#
# Key threats: XSS, CSRF, clickjacking, data leakage.
#
# ## Core mitigations
# - Output encoding
# - Content Security Policy (CSP)
# - SameSite cookies
# - CSRF tokens
