# %% [markdown]
# # Infrastructure as Code (IaC)
#
# Terraform concepts (state, modules, environments) and IaC best practices.
#
# ## Topics
# - (add notebooks in this folder)
#
# ## Notes
# - (key takeaways / gotchas / references)
